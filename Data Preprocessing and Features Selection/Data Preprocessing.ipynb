# %% [markdown]
# # Data Preprocessing Method

# %% [markdown]
# ## Step 1: Import required libraries

# %%
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Step 2: Load the dataset

# %%
df = pd.read_csv("PhD_Dataset_Incidence.csv")

# View first 5 rows
df.head()
# Out:
#     hh  sex  age  lga  edu  mrt_status  fmly_size  m_income  cfuel  ipollut  \
# 0  1.0    1  3.0    1    6           1          4         4      6        1
# 1  2.0    1  3.0    1    7           1          7         7      6        1
# 2  3.0    1  3.0    1    6           1          5         5      6        1
# 3  4.0    1  3.0    1    6           1          6         3      6        1
# 4  5.0    1  4.0    1    5           1         10         7      6        1
#
#    ...  h_facility  dist_hfacility  illiness  waterborne  resp_disease  \
# 0  ...         1.0             1.0       2.0           0           0.0
# 1  ...         1.0             0.5       5.0           2           0.0
# 2  ...         1.0             0.5       2.0           0           0.0
# 3  ...         1.0             0.5       4.0           0           0.0
# 4  ...         1.0             3.0      10.0           2           0.0
#
#    eye_disease  child_death maternalcare  square_meal health_ins
# ...

# %% [markdown]
# ## Step 3: Check number of rows and columns

# %%
df.shape
# Out:
# (499, 52)

# %% [markdown]
# ## Step 4: View all column names

# %%
df.columns
# Out:
# Index(['hh', 'sex', 'age', 'lga', 'edu', 'mrt_status', 'fmly_size', 'm_income',
#        'cfuel', 'ipollut', 'rbiomass', 'dailycook', 'avl_lpg', 'aff_lpg',
#        'Electricity', 'hrs_elect', 'aff_elct', 'exp_elct', 'source_light',
#        'exp_lpg', 'exp_nonlpg', 'aff_solide', 'hh_appl', 'edu_appl', 'c_appl',
#        'occupation', 'hh_exp', 'housing', 'wall', 'floor', 'rooms', 'bank',
#        'bank_acct', 'b_facility', 'road', 'raod_dist', 'schl', 'type_sch',
#        'dst_sch', 'sch_days', 'sch_drpout', 'chld_labor', 'h_facility',
#        'dist_hfacility', 'illiness', 'waterborne', 'resp_disease',
#        'eye_disease', 'child_death', 'maternalcare', 'square_meal',
#        'health_ins'],
#       dtype='object')

# %% [markdown]
# ## Step 5: Check data types and missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 52 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   hh              167 non-null    float64
#  1   sex             499 non-null    int64
#  2   age             497 non-null    float64
#  3   lga             499 non-null    int64
#  4   edu             499 non-null    int64
#  5   mrt_status      499 non-null    int64
#  6   fmly_size       499 non-null    int64
#  7   m_income        499 non-null    int64
#  8   cfuel           499 non-null    int64
#  9   ipollut         499 non-null    int64
#  10  rbiomass        374 non-null    float64
#  11  dailycook       497 non-null    float64
#  12  avl_lpg         499 non-null    int64
#  13  aff_lpg         499 non-null    int64
#  14  Electricity     497 non-null    float64
#  15  hrs_elect       499 non-null    float64
#  16  aff_elct        485 non-null    float64
# ...

# %% [markdown]
# ## Step 6: Remove commas from numeric values

# %%
df = df.replace(',', '', regex=True)

# Convert numeric columns safely
for col in df.columns:
    try:
        df[col] = pd.to_numeric(df[col])
    except:
        pass

# Fill missing values
df.fillna(df.median(numeric_only=True), inplace=True)

# Check dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 52 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   hh              499 non-null    float64
#  1   sex             499 non-null    int64
#  2   age             499 non-null    float64
#  3   lga             499 non-null    int64
#  4   edu             499 non-null    int64
#  5   mrt_status      499 non-null    int64
#  6   fmly_size       499 non-null    int64
#  7   m_income        499 non-null    int64
#  8   cfuel           499 non-null    int64
#  9   ipollut         499 non-null    int64
#  10  rbiomass        499 non-null    float64
#  11  dailycook       499 non-null    float64
#  12  avl_lpg         499 non-null    int64
#  13  aff_lpg         499 non-null    int64
#  14  Electricity     499 non-null    float64
#  15  hrs_elect       499 non-null    float64
#  16  aff_elct        499 non-null    float64
# ...

# %% [markdown]
# ## Step 7: Remove duplicate rows

# %%
df = df.drop_duplicates()

df.shape
# Out:
# (499, 52)

# %% [markdown]
# ## Step 8: Statistical summary

# %%
df.describe()
# Out:
#                hh         sex         age         lga         edu  mrt_status  \
# count  167.000000  499.000000  497.000000  499.000000  499.000000  499.000000
# mean    84.059880    1.036072    3.519115    3.468938    3.416834    1.472946
# std     48.284261    0.186657    1.236270    1.868288    1.604023    1.062679
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%     42.500000    1.000000    3.000000    2.000000    2.000000    1.000000
# 50%     84.000000    1.000000    3.000000    4.000000    3.000000    1.000000
# 75%    125.500000    1.000000    4.000000    5.000000    5.000000    1.000000
# max    167.000000    2.000000    6.000000    6.000000    7.000000    4.000000
#
#         fmly_size    m_income       cfuel     ipollut  ...  h_facility  \
# count  499.000000  499.000000  499.000000  499.000000  ...   493.00000
# mean     8.665331    2.869739    3.649299    1.404810  ...     1.03854
# ...

# %% [markdown]
# ## Step 9: Create Energy Poverty target variable

# %%
df['energy_poor'] = np.where(
    (df['Electricity'] == 0) | (df['hrs_elect'] < 6) | (df['cfuel'] == 3),
    1, 0
)

df['energy_poor'].value_counts()
# Out:
# energy_poor
# 1    395
# 0    104
# Name: count, dtype: int64
