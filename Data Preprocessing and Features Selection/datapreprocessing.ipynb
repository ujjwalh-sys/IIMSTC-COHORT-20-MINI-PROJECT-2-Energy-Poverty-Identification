# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Copy of PhD_Dataset_Incidence.csv")
dataset
# Out:
#       hh  sex  age  lga  edu  mrt_status  fmly_size  m_income  cfuel  ipollut  \
# 0    1.0    1  3.0    1    6           1          4         4      6        1
# 1    2.0    1  3.0    1    7           1          7         7      6        1
# 2    3.0    1  3.0    1    6           1          5         5      6        1
# 3    4.0    1  3.0    1    6           1          6         3      6        1
# 4    5.0    1  4.0    1    5           1         10         7      6        1
# ..   ...  ...  ...  ...  ...         ...        ...       ...    ...      ...
# 494  NaN    2  2.0    5    2           2          5         1      4        1
# 495  NaN    1  2.0    5    6           4          5         4      6        1
# 496  NaN    1  3.0    5    5           4          4         3      7        1
# 497  NaN    1  3.0    5    3           1          4         2      4        2
# 498  NaN    1  3.0    5    4           1          5         2      3        2
#
# ...

# %%
dataset.columns=dataset.columns.str.lower()
dataset
# Out:
#       hh  sex  age  lga  edu  mrt_status  fmly_size  m_income  cfuel  ipollut  \
# 0    1.0    1  3.0    1    6           1          4         4      6        1
# 1    2.0    1  3.0    1    7           1          7         7      6        1
# 2    3.0    1  3.0    1    6           1          5         5      6        1
# 3    4.0    1  3.0    1    6           1          6         3      6        1
# 4    5.0    1  4.0    1    5           1         10         7      6        1
# ..   ...  ...  ...  ...  ...         ...        ...       ...    ...      ...
# 494  NaN    2  2.0    5    2           2          5         1      4        1
# 495  NaN    1  2.0    5    6           4          5         4      6        1
# 496  NaN    1  3.0    5    5           4          4         3      7        1
# 497  NaN    1  3.0    5    3           1          4         2      4        2
# 498  NaN    1  3.0    5    4           1          5         2      3        2
#
# ...

# %%
dataset.dtypes
# Out:
# hh                float64
# sex                 int64
# age               float64
# lga                 int64
# edu                 int64
# mrt_status          int64
# fmly_size           int64
# m_income            int64
# cfuel               int64
# ipollut             int64
# rbiomass          float64
# dailycook         float64
# avl_lpg             int64
# aff_lpg             int64
# electricity       float64
# hrs_elect         float64
# aff_elct          float64
# exp_elct           object
# source_light      float64
# exp_lpg            object
# exp_nonlpg         object
# aff_solide          int64
# hh_appl             int64
# edu_appl            int64
# c_appl              int64
# occupation          int64
# hh_exp             object
# housing           float64
# wall              float64
# floor             float64
# rooms             float64
# bank              float64
# bank_acct         float64
# b_facility        float64
# road              float64
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 52 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   hh              167 non-null    float64
#  1   sex             499 non-null    int64
#  2   age             497 non-null    float64
#  3   lga             499 non-null    int64
#  4   edu             499 non-null    int64
#  5   mrt_status      499 non-null    int64
#  6   fmly_size       499 non-null    int64
#  7   m_income        499 non-null    int64
#  8   cfuel           499 non-null    int64
#  9   ipollut         499 non-null    int64
#  10  rbiomass        374 non-null    float64
#  11  dailycook       497 non-null    float64
#  12  avl_lpg         499 non-null    int64
#  13  aff_lpg         499 non-null    int64
#  14  electricity     497 non-null    float64
#  15  hrs_elect       499 non-null    float64
#  16  aff_elct        485 non-null    float64
# ...

# %%
dataset['hh']=dataset['hh'].fillna(0).astype(int)
dataset['m_income']=dataset['m_income'].astype(float)
dataset['cfuel']=dataset['cfuel'].astype('category')
dataset['electricity']=dataset['electricity'].astype('category')

# %%
dataset['m_income']=pd.to_numeric(dataset['m_income'],errors='coerce')

# %%
print(dataset.dtypes)
# Out:
# hh                   int64
# sex                  int64
# age                float64
# lga                  int64
# edu                  int64
# mrt_status           int64
# fmly_size            int64
# m_income           float64
# cfuel             category
# ipollut              int64
# rbiomass           float64
# dailycook          float64
# avl_lpg              int64
# aff_lpg              int64
# electricity       category
# hrs_elect          float64
# aff_elct           float64
# exp_elct            object
# source_light       float64
# exp_lpg             object
# exp_nonlpg          object
# aff_solide           int64
# hh_appl              int64
# edu_appl             int64
# c_appl               int64
# occupation           int64
# hh_exp              object
# housing            float64
# wall               float64
# floor              float64
# rooms              float64
# bank               float64
# bank_acct          float64
# b_facility         float64
# ...

# %%
dataset.to_csv("cleaned_dataset.csv",index=False)
